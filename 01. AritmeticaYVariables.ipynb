# %% [markdown]
# # Aritmética y Variables
#
# En este JNB se revisará el tema de Aritmética y Variables

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Aritmetica en Python
#
# Se utiliza los números enteros y flotantes junto con operadores aritméticos para realizar cálculos matemáticos.

# %%
print(3 + 5)  # Suma
# Out:
# 8

# %%
3 + 5
# Out:
# 8

# %%
print(((1 + 3) * (9 - 2) / 2) ** 2)
# Out:
# 196.0
