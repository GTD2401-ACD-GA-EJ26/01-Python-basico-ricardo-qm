# %% [markdown]
# # Introducción a Listas
#
# En este JNB se revisará el tema de Introducción a Listas

# %%
flowers = "pink primrose,hard-leaved pocket orchid,canterbury bells,sweet pea,english marigold,tiger lily,moon orchid,bird of paradise,monkshood,globe thistle"

print(type(flowers))
print(flowers)
# Out:
# <class 'str'>
# pink primrose,hard-leaved pocket orchid,canterbury bells,sweet pea,english marigold,tiger lily,moon orchid,bird of paradise,monkshood,globe thistle

# %%
flowers_list = ["pink primrose", "hard-leaved pocket orchid", "canterbury bells", "sweet pea", "english marigold", "tiger lily", "moon orchid", "bird of paradise", "monkshood", "globe thistle"]

print(type(flowers_list))
print(flowers_list)
# Out:
# <class 'list'>
# ['pink primrose', 'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea', 'english marigold', 'tiger lily', 'moon orchid', 'bird of paradise', 'monkshood', 'globe thistle']

# %%
# The list has ten entries
print(len(flowers_list))
# Out:
# 10

# %%
print("First entry:", flowers_list[0])
print("Second entry:", flowers_list[1])

# The list has length ten, so we refer to final entry with 9
print("Last entry:", flowers_list[9])
# Out:
# First entry: pink primrose
# Second entry: hard-leaved pocket orchid
# Last entry: globe thistle

# %%
# The list has length ten, so we refer to final entry with -1
print("Last entry:", flowers_list[-1])
# Out:
# Last entry: globe thistle

# %%
print("First three entries:", flowers_list[:3])
print("Final two entries:", flowers_list[-2:])
# Out:
# First three entries: ['pink primrose', 'hard-leaved pocket orchid', 'canterbury bells']
# Final two entries: ['monkshood', 'globe thistle']

# %%
print("Entries from 3 to 6:", flowers_list[3:7])
# Out:
# Entries from 3 to 6: ['sweet pea', 'english marigold', 'tiger lily', 'moon orchid']

# %%
# Imprime la lista en sentido inverso
print("Entries in reverse order:", flowers_list[::-1])
# Out:
# Entries in reverse order: ['globe thistle', 'monkshood', 'bird of paradise', 'moon orchid', 'tiger lily', 'english marigold', 'sweet pea', 'canterbury bells', 'hard-leaved pocket orchid', 'pink primrose']

# %%
# Imprime los pares de la lista desde el tres hasta el ocho de dos en dos
print("Entries from 3 to 8 with step 2:", flowers_list[3:9:2])
# Out:
# Entries from 3 to 8 with step 2: ['sweet pea', 'tiger lily', 'bird of paradise']

# %%
# Haz lo mismo pero en sentido contrario
print("Entries from 8 to 3 with step -2:", flowers_list[8:2:-2])
# Out:
# Entries from 8 to 3 with step -2: ['monkshood', 'moon orchid', 'english marigold']

# %%
# Haz el mismo ejercicio anterior pero con indices negativos

print("Entries from -7 to -2 with step 2:", flowers_list[-7:-1:2])
# Out:
# Entries from -7 to -2 with step 2: ['sweet pea', 'tiger lily', 'bird of paradise']

# %%
flowers_list.remove("globe thistle")
print(flowers_list)
# Out:
# ['pink primrose', 'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea', 'english marigold', 'tiger lily', 'moon orchid', 'bird of paradise', 'monkshood']

# %%
flowers_list.append("snapdragon")
print(flowers_list)
# Out:
# ['pink primrose', 'hard-leaved pocket orchid', 'canterbury bells', 'sweet pea', 'english marigold', 'tiger lily', 'moon orchid', 'bird of paradise', 'monkshood', 'snapdragon']

# %%
hardcover_sales = [139, 128, 172, 139, 191, 168, 170]

# %%
print("Length of the list:", len(hardcover_sales))
print("Entry at index 2:", hardcover_sales[2])
# Out:
# Length of the list: 7
# Entry at index 2: 172

# %%
print("Minimum:", min(hardcover_sales))
print("Maximum:", max(hardcover_sales))
# Out:
# Minimum: 128
# Maximum: 191

# %%
print("Total books sold in one week:", sum(hardcover_sales))
# Out:
# Total books sold in one week: 1107

# %%
print("Average books sold in first five days:", sum(hardcover_sales[:5])/5)
# Out:
# Average books sold in first five days: 153.8
